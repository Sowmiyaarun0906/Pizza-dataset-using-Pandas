# 49567       49568  2015-021347  31-12-2015  21:14:37      bbq_ckn    M
# 49569       49570  2015-021348  31-12-2015  21:23:10  four_cheese    L
# 49571       49572  2015-021348  31-12-2015  21:23:10  ckn_alfredo    M
#
#           type  price
# 1      classic  16.00
# 2       veggie  16.00
# 4       veggie  18.50
# ...

# %%
df[(df["price"]>15)&(df["price"]<20)].count()
# Out:
# Unnamed: 0    17986
# id            17986
# date          17986
# time          17986
# name          17986
# size          17986
# type          17986
# price         17986
# dtype: int64

# %%
df[(df["price"]>1)&(df["price"]<15)]
# Out:
#        Unnamed: 0           id        date      time          name size  \
# 0               1  2015-000001  01-01-2015  11:38:36      hawaiian    M
# 10             11  2015-000006  01-01-2015  12:29:36       bbq_ckn    S
# 11             12  2015-000006  01-01-2015  12:29:36     the_greek    S
# 12             13  2015-000007  01-01-2015  12:50:37  spinach_supr    S
# 13             14  2015-000008  01-01-2015  12:51:37  spinach_supr    S
# ...           ...          ...         ...       ...           ...  ...
# 49563       49564  2015-021346  31-12-2015  20:51:07      cali_ckn    S
# 49564       49565  2015-021346  31-12-2015  20:51:07      big_meat    S
# 49568       49569  2015-021347  31-12-2015  21:14:37  peppr_salami    S
# 49570       49571  2015-021348  31-12-2015  21:23:10    napolitana    S
# 49573       49574  2015-021350  31-12-2015  23:02:05       bbq_ckn    S
#
#           type  price
# 0      classic  13.25
# 10     chicken  12.75
# 11     classic  12.00
# ...

# %%
df[(df["price"]>1)&(df["price"]<15)].count()
# Out:
# Unnamed: 0    16318
# id            16318
# date          16318
# time          16318
# name          16318
# size          16318
# type          16318
# price         16318
# dtype: int64

# %%
df.iloc[25]
# Out:
# Unnamed: 0             26
# id            2015-000011
# date           01-01-2015
# time             13:02:59
# name            pepperoni
# size                    L
# type              classic
# price               15.25
# Name: 25, dtype: object

# %%
df.loc[25,"name"]
# Out:
# 'pepperoni'

# %%
df.loc[25,"size"]
# Out:
# 'L'

# %%
df.loc[25,"price"]
# Out:
# np.float64(15.25)

# %%
df.loc[[25],["id"]]
# Out:
#              id
# 25  2015-000011

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (49574, 8)

# %%
df.size
# Out:
# 396592

# %%
df.T
# Out:
#                   0            1            2            3            4      \
# Unnamed: 0            1            2            3            4            5
# id          2015-000001  2015-000002  2015-000002  2015-000002  2015-000002
# date         01-01-2015   01-01-2015   01-01-2015   01-01-2015   01-01-2015
# time           11:38:36     11:57:40     11:57:40     11:57:40     11:57:40
# name           hawaiian  classic_dlx     mexicana     thai_ckn  five_cheese
# size                  M            M            M            L            L
# type            classic      classic       veggie      chicken       veggie
# price             13.25         16.0         16.0        20.75         18.5
#
#                   5            6            7            8            9      \
# Unnamed: 0            6            7            8            9           10
# id          2015-000002  2015-000003  2015-000003  2015-000004  2015-000005
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0           id        date      time         name size  \
# 0               1  2015-000001  01-01-2015  11:38:36     hawaiian    M
# 1               2  2015-000002  01-01-2015  11:57:40  classic_dlx    M
# 2               3  2015-000002  01-01-2015  11:57:40     mexicana    M
# 3               4  2015-000002  01-01-2015  11:57:40     thai_ckn    L
# 4               5  2015-000002  01-01-2015  11:57:40  five_cheese    L
# ...           ...          ...         ...       ...          ...  ...
# 49569       49570  2015-021348  31-12-2015  21:23:10  four_cheese    L
# 49570       49571  2015-021348  31-12-2015  21:23:10   napolitana    S
# 49571       49572  2015-021348  31-12-2015  21:23:10  ckn_alfredo    M
# 49572       49573  2015-021349  31-12-2015  22:09:54     mexicana    L
# 49573       49574  2015-021350  31-12-2015  23:02:05      bbq_ckn    S
#
#           type  price
# 0      classic  13.25
# 1      classic  16.00
# ...

# %%
df["price"].sum()
# Out:
# np.float64(817860.05)

# %%
df["price"].mean()
# Out:
# np.float64(16.497761931657724)

# %%
df["price"].median()
# Out:
# np.float64(16.5)

# %%
df["price"].mode()
# Out:
# 0    20.75
# Name: price, dtype: float64

# %%
df["price"].std()
# Out:
# np.float64(3.621953739524801)

# %%
df["price"].min()
# Out:
# np.float64(9.75)

# %%
df["price"].max()
# Out:
# np.float64(35.95)

# %%
df["price"].prod()
# Out:
# C:\Python\Lib\site-packages\numpy\_core\_methods.py:57: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# np.float64(inf)

# %%
df["price"].cumsum()
# Out:
# 0            13.25
# 1            29.25
# 2            45.25
# 3            66.00
# 4            84.50
#            ...
# 49569    817798.30
# 49570    817810.30
# 49571    817827.05
# 49572    817847.30
# 49573    817860.05
# Name: price, Length: 49574, dtype: float64

# %%
df["price"].head(1000).cumsum()
# Out:
# 0         13.25
# 1         29.25
# 2         45.25
# 3         66.00
# 4         84.50
#          ...
# 995    16483.70
# 996    16503.95
# 997    16515.95
# 998    16532.45
# 999    16548.45
# Name: price, Length: 1000, dtype: float64

# %%
df["price"].head(20).prod()
# Out:
# np.float64(1.587873207745296e+24)

# %%
df["price"].describe()
# Out:
# count    49574.000000
# mean        16.497762
# std          3.621954
# min          9.750000
# 25%         12.750000
# 50%         16.500000
# 75%         20.250000
# max         35.950000
# Name: price, dtype: float64

# %%
df["price"].abs()
# Out:
# 0        13.25
# 1        16.00
# 2        16.00
# 3        20.75
# 4        18.50
#          ...
# 49569    17.95
# 49570    12.00
# 49571    16.75
# 49572    20.25
# 49573    12.75
# Name: price, Length: 49574, dtype: float64

# %%
df["size"].count()
# Out:
# np.int64(49574)

# %%
df["price"].head(5).cumprod()
# Out:
# 0         13.25
# 1        212.00
# 2       3392.00
# 3      70384.00
# 4    1302104.00
# Name: price, dtype: float64

# %%
df.loc[1:5,"name":"price"]
# Out:
#           name size     type  price
# 1  classic_dlx    M  classic  16.00
# 2     mexicana    M   veggie  16.00
# 3     thai_ckn    L  chicken  20.75
# 4  five_cheese    L   veggie  18.50
# 5    ital_supr    L  supreme  20.75
